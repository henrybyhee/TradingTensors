# %% [markdown]
# # Enhancing State Space with Planetry Data?
#
# In this experiment, lets explore how the position of Moon affect our Agent's behaviour. Planet Calculation is made based datetime values using Swiss Ephemeris method (pyswisseph). (This experiment is purely for fun as there has been no proven evidence in the predictive power of this additional information)

# %%
from tradingtensors.Environments.CustomEnvs import OandaEnv
from tradingtensors.Agents.Q_learning import DQNAgent

#Define Environment
env = OandaEnv(
    INSTRUMENT = "EUR_USD", 
    TIMEFRAME = "H1", 
    lookback_period= 3,
    trade_duration=3,
    planet_data={"Moon" : ["right asc.", "declination", "distance"]}, # Require these coordinates of Moon
    PLANET_FORWARD_PERIOD=2, #Look ahead 2 periods of Moon Coordinates 

)

#Define Agent - DQN

PATH = r'Enter destination files'

agent = DQNAgent(
    env= env,
    PARENT_PATH = PATH #Path to save your models
)
# Out:
# C:\Users\Henry\Anaconda2\envs\tensorflow\lib\site-packages\matplotlib\cbook.py:136: MatplotlibDeprecationWarning: The finance module has been deprecated in mpl 2.0 and will be removed in mpl 2.2. Please use the module mpl_finance instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
agent.train(
CONVERGENCE_THRESHOLD=700 #Setting a more stringent convergence criteria than before
) #use Default Settings
# Out:
# End of Episode 1, Total Reward is 98.4, Average Reward is 1.014
# Percentage of time spent on exploring (Random Action): 96 %
#
# End of Episode 2, Total Reward is -236.6, Average Reward is -2.465
# Percentage of time spent on exploring (Random Action): 93 %
#
# End of Episode 3, Total Reward is 195.0, Average Reward is 2.031
# Percentage of time spent on exploring (Random Action): 90 %
#
# End of Episode 4, Total Reward is 207.0, Average Reward is 2.179
# Percentage of time spent on exploring (Random Action): 86 %
#
# End of Episode 5, Total Reward is -9.7, Average Reward is -0.099
# Percentage of time spent on exploring (Random Action): 83 %
#
# End of Episode 6, Total Reward is 73.8, Average Reward is 0.724
# Percentage of time spent on exploring (Random Action): 80 %
#
# End of Episode 7, Total Reward is -48.4, Average Reward is -0.504
# Percentage of time spent on exploring (Random Action): 77 %
#
# End of Episode 8, Total Reward is 38.2, Average Reward is 0.382
# Percentage of time spent on exploring (Random Action): 73 %
#
# End of Episode 9, Total Reward is 394.2, Average Reward is 3.827
# Percentage of time spent on exploring (Random Action): 70 %
#
# End of Episode 10, Total Reward is 238.7, Average Reward is 2.363
# Percentage of time spent on exploring (Random Action): 67 %
#
# End of Episode 11, Total Reward is 428.8, Average Reward is 4.246
# Percentage of time spent on exploring (Random Action): 63 %
#
# End of Episode 12, Total Reward is 323.4, Average Reward is 3.022
# Percentage of time spent on exploring (Random Action): 60 %
#
# End of Episode 13, Total Reward is 73.7, Average Reward is 0.702
# Percentage of time spent on exploring (Random Action): 57 %
#
# End of Episode 14, Total Reward is 153.7, Average Reward is 1.478
# Percentage of time spent on exploring (Random Action): 54 %
#
# End of Episode 15, Total Reward is 185.9, Average Reward is 1.823
# Percentage of time spent on exploring (Random Action): 50 %
#
# End of Episode 16, Total Reward is 52.2, Average Reward is 0.502
# Percentage of time spent on exploring (Random Action): 47 %
#
# End of Episode 17, Total Reward is 335.9, Average Reward is 3.199
# Percentage of time spent on exploring (Random Action): 44 %
#
# End of Episode 18, Total Reward is 401.0, Average Reward is 3.931
# Percentage of time spent on exploring (Random Action): 40 %
#
# End of Episode 19, Total Reward is 489.6, Average Reward is 4.663
# Percentage of time spent on exploring (Random Action): 37 %
#
# End of Episode 20, Total Reward is 306.8, Average Reward is 2.841
# Percentage of time spent on exploring (Random Action): 34 %
#
# End of Episode 21, Total Reward is 238.7, Average Reward is 2.295
# Percentage of time spent on exploring (Random Action): 31 %
#
# End of Episode 22, Total Reward is 458.5, Average Reward is 4.325
# Percentage of time spent on exploring (Random Action): 27 %
#
# End of Episode 23, Total Reward is 528.4, Average Reward is 4.718
# Percentage of time spent on exploring (Random Action): 24 %
#
# End of Episode 24, Total Reward is 526.2, Average Reward is 4.918
# Percentage of time spent on exploring (Random Action): 21 %
#
# End of Episode 25, Total Reward is 538.2, Average Reward is 5.030
# Percentage of time spent on exploring (Random Action): 17 %
#
# End of Episode 26, Total Reward is 445.6, Average Reward is 4.014
# Percentage of time spent on exploring (Random Action): 14 %
#
# End of Episode 27, Total Reward is 345.3, Average Reward is 3.111
# Percentage of time spent on exploring (Random Action): 11 %
#
# End of Episode 28, Total Reward is 764.0, Average Reward is 6.821
# Percentage of time spent on exploring (Random Action): 8 %
#
# End of Episode 29, Total Reward is 434.8, Average Reward is 3.882
# Percentage of time spent on exploring (Random Action): 4 %
#
# End of Episode 30, Total Reward is 747.8, Average Reward is 6.677
# Percentage of time spent on exploring (Random Action): 2 %
#
# End of Episode 31, Total Reward is 592.8, Average Reward is 5.246
# Percentage of time spent on exploring (Random Action): 2 %
# INFO:tensorflow:C:\Users\Henry\Documents\Python Stuff\Upwork Trial\Forex Ai\github\tradingtensors\Examples\Models\2216_Episode31.ckpt is not in all_model_checkpoint_paths. Manually adding it.
#
# End of Episode 32, Total Reward is 479.6, Average Reward is 4.207
# Percentage of time spent on exploring (Random Action): 2 %
# INFO:tensorflow:C:\Users\Henry\Documents\Python Stuff\Upwork Trial\Forex Ai\github\tradingtensors\Examples\Models\2216_Episode32.ckpt is not in all_model_checkpoint_paths. Manually adding it.
#
# End of Episode 33, Total Reward is 545.8, Average Reward is 4.830
# Percentage of time spent on exploring (Random Action): 2 %
# INFO:tensorflow:C:\Users\Henry\Documents\Python Stuff\Upwork Trial\Forex Ai\github\tradingtensors\Examples\Models\2216_Episode33.ckpt is not in all_model_checkpoint_paths. Manually adding it.
#
# End of Episode 34, Total Reward is 628.3, Average Reward is 5.560
# Percentage of time spent on exploring (Random Action): 2 %
# INFO:tensorflow:C:\Users\Henry\Documents\Python Stuff\Upwork Trial\Forex Ai\github\tradingtensors\Examples\Models\2216_Episode34.ckpt is not in all_model_checkpoint_paths. Manually adding it.
#
# End of Episode 35, Total Reward is 785.0, Average Reward is 6.886
# Percentage of time spent on exploring (Random Action): 2 %
# INFO:tensorflow:C:\Users\Henry\Documents\Python Stuff\Upwork Trial\Forex Ai\github\tradingtensors\Examples\Models\2216_Episode35.ckpt is not in all_model_checkpoint_paths. Manually adding it.
#
# End of Episode 36, Total Reward is 426.7, Average Reward is 3.710
# Percentage of time spent on exploring (Random Action): 2 %
# INFO:tensorflow:C:\Users\Henry\Documents\Python Stuff\Upwork Trial\Forex Ai\github\tradingtensors\Examples\Models\2216_Episode36.ckpt is not in all_model_checkpoint_paths. Manually adding it.
#
# End of Episode 37, Total Reward is 740.7, Average Reward is 6.497
# Percentage of time spent on exploring (Random Action): 2 %
# INFO:tensorflow:C:\Users\Henry\Documents\Python Stuff\Upwork Trial\Forex Ai\github\tradingtensors\Examples\Models\2216_Episode37.ckpt is not in all_model_checkpoint_paths. Manually adding it.
#
# End of Episode 38, Total Reward is 876.3, Average Reward is 7.620
# Percentage of time spent on exploring (Random Action): 2 %
# INFO:tensorflow:C:\Users\Henry\Documents\Python Stuff\Upwork Trial\Forex Ai\github\tradingtensors\Examples\Models\2216_Episode38.ckpt is not in all_model_checkpoint_paths. Manually adding it.
#
# End of Episode 39, Total Reward is 532.4, Average Reward is 4.754
# Percentage of time spent on exploring (Random Action): 2 %
# INFO:tensorflow:C:\Users\Henry\Documents\Python Stuff\Upwork Trial\Forex Ai\github\tradingtensors\Examples\Models\2216_Episode39.ckpt is not in all_model_checkpoint_paths. Manually adding it.
#
# End of Episode 40, Total Reward is 810.3, Average Reward is 7.171
# Percentage of time spent on exploring (Random Action): 2 %
# INFO:tensorflow:C:\Users\Henry\Documents\Python Stuff\Upwork Trial\Forex Ai\github\tradingtensors\Examples\Models\2216_Episode40.ckpt is not in all_model_checkpoint_paths. Manually adding it.
#
# End of Episode 41, Total Reward is 798.3, Average Reward is 7.003
# Percentage of time spent on exploring (Random Action): 2 %
# INFO:tensorflow:C:\Users\Henry\Documents\Python Stuff\Upwork Trial\Forex Ai\github\tradingtensors\Examples\Models\2216_Episode41.ckpt is not in all_model_checkpoint_paths. Manually adding it.
#
# End of Episode 42, Total Reward is 690.2, Average Reward is 6.054
# Percentage of time spent on exploring (Random Action): 2 %
# INFO:tensorflow:C:\Users\Henry\Documents\Python Stuff\Upwork Trial\Forex Ai\github\tradingtensors\Examples\Models\2216_Episode42.ckpt is not in all_model_checkpoint_paths. Manually adding it.
#
# End of Episode 43, Total Reward is 834.9, Average Reward is 7.324
# Percentage of time spent on exploring (Random Action): 2 %
# INFO:tensorflow:C:\Users\Henry\Documents\Python Stuff\Upwork Trial\Forex Ai\github\tradingtensors\Examples\Models\2216_Episode43.ckpt is not in all_model_checkpoint_paths. Manually adding it.
#
# End of Episode 44, Total Reward is 906.4, Average Reward is 8.021
# Percentage of time spent on exploring (Random Action): 2 %
# INFO:tensorflow:C:\Users\Henry\Documents\Python Stuff\Upwork Trial\Forex Ai\github\tradingtensors\Examples\Models\2216_Episode44.ckpt is not in all_model_checkpoint_paths. Manually adding it.
#
# End of Episode 45, Total Reward is 584.0, Average Reward is 5.214
# Percentage of time spent on exploring (Random Action): 2 %
#
# End of Episode 46, Total Reward is 729.3, Average Reward is 6.454
# Percentage of time spent on exploring (Random Action): 2 %
# INFO:tensorflow:C:\Users\Henry\Documents\Python Stuff\Upwork Trial\Forex Ai\github\tradingtensors\Examples\Models\2216_Episode46.ckpt is not in all_model_checkpoint_paths. Manually adding it.
#
# End of Episode 47, Total Reward is 763.7, Average Reward is 6.758
# Percentage of time spent on exploring (Random Action): 2 %
# INFO:tensorflow:C:\Users\Henry\Documents\Python Stuff\Upwork Trial\Forex Ai\github\tradingtensors\Examples\Models\2216_Episode47.ckpt is not in all_model_checkpoint_paths. Manually adding it.
#
# End of Episode 48, Total Reward is 735.7, Average Reward is 6.569
# Percentage of time spent on exploring (Random Action): 2 %
# INFO:tensorflow:C:\Users\Henry\Documents\Python Stuff\Upwork Trial\Forex Ai\github\tradingtensors\Examples\Models\2216_Episode48.ckpt is not in all_model_checkpoint_paths. Manually adding it.
#
# CONVERGED!

# %%
agent.trainSummary()
# Out:
# ########   RANK 1   ###########
# Episode          | 44
# Total Reward     | 906.40
# Average Reward   | 8.02
# ################################
#
#
# ########   RANK 2   ###########
# Episode          | 38
# Total Reward     | 876.30
# Average Reward   | 7.62
# ################################
#
#
# ########   RANK 3   ###########
# Episode          | 43
# Total Reward     | 834.90
# Average Reward   | 7.32
# ################################
#
#
# ########   RANK 4   ###########
# Episode          | 40
# Total Reward     | 810.30
# Average Reward   | 7.17
# ################################
#
#
# ########   RANK 5   ###########
# Episode          | 41
# Total Reward     | 798.30
# Average Reward   | 7.00
# ################################
#
#
# ########   RANK 6   ###########
# Episode          | 35
# Total Reward     | 785.00
# Average Reward   | 6.89
# ################################
#
#
# ########   RANK 7   ###########
# Episode          | 47
# Total Reward     | 763.70
# Average Reward   | 6.76
# ################################
#
#
# ########   RANK 8   ###########
# Episode          | 48
# Total Reward     | 735.70
# Average Reward   | 6.57
# ################################
#
#
# ########   RANK 9   ###########
# Episode          | 37
# Total Reward     | 740.70
# Average Reward   | 6.50
# ################################
#
#
# ########   RANK 10   ###########
# Episode          | 46
# Total Reward     | 729.30
# Average Reward   | 6.45
# ################################

# %%
'''Surprisingly, model is able to converge even with a more stringent criteria. Maybe pure luck?'''
agent.episodeReview(44)
# Out:
# Summary Statistics for Episode 44
#
# Total Trades            | 113        (Buy)48       (Sell)65
# Profit (in pips)        | 906.40   (Buy)452.80   (Sell)453.60
# Win Ratio               | 75.22%    (Buy)77.08%   (Sell)73.85 %
# Average Trade Duration  | 2.97

# %%
''' Test Case does not do that badly either'''
agent.test(44)
# Out:
# INFO:tensorflow:Restoring parameters from C:\Users\Henry\Documents\Python Stuff\Upwork Trial\Forex Ai\github\tradingtensors\Examples\Models\2216_Episode44.ckpt
# Summary Statistics for Episode 0
#
# Total Trades            | 48        (Buy)19       (Sell)29
# Profit (in pips)        | 85.60   (Buy)59.90   (Sell)25.70
# Win Ratio               | 54.17%    (Buy)63.16%   (Sell)48.28 %
# Average Trade Duration  | 3.00

# %% [markdown]
# #  Live Trading

# %%
'''Ready to take Model 44 live?'''
agent.liveTrading(
    MODEL_EPS=44
)
